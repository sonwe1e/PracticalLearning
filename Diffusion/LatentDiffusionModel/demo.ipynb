# %%
from generator import Generator

print("Loading Model")
G = Generator()
print("Model Loaded")
# Out:
# Loading Model
# Model Loaded

# %%
r = G.generate(["bike"], height=64, width=64)
# Out:
# 100%|██████████| 50/50 [00:02<00:00, 21.88it/s]

# %%
import matplotlib.pyplot as plt

plt.imshow(r[0].permute(1, 2, 0).cpu().detach().numpy())
